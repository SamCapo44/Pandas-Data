# %% [markdown]
# # My First Notebook

# %%
import pandas as pd
import numpy as np

# %%
#creating an array
data = np.array([[1,4], [2,5], [3,6]])

# %%
#creating a dataframe
df = pd.DataFrame(data, index=['row1', 'row2', 'row3'],
            columns=['col1', 'col2'])

# %%
#showing the dataframe
df
# Out:
#       col1  col2
# row1     1     4
# row2     2     5
# row3     3     6

# %%
#creating an array
data = [[1,4], [2,5], [3,6]]

# %%
#creating a dataframe
df = pd.DataFrame(data, index=['row1', 'row2', 'row3'],
            columns=['col1', 'col2'])

# %%
#showing the dataframe
df
# Out:
#       col1  col2
# row1     1     4
# row2     2     5
# row3     3     6

# %% [markdown]
# Creating DataFrame from dictionary

# %%
# list dataframe
states = ['Lagos', 'Accra', 'Kumasi', 'Tema']
population = [2455445, 6532234, 765445, 23456765]

# %%
# storing list within a dictionary
dict_states = {'States': states, 'Population': population}

# %%
#creating the dataframe
df_population = pd.DataFrame(dict_states)

# %%
df_population
# Out:
#    States  Population
# 0   Lagos     2455445
# 1   Accra     6532234
# 2  Kumasi      765445
# 3    Tema    23456765

# %% [markdown]
# creating dataframe from csv

# %%
#reading the csv file
df_exams = pd.read_csv('StudentsPerformance.csv')

# %%
#show first five rows in dataframe
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
# [1000 rows x 8 columns]

# %%
df_exams.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df_exams.tail()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86

# %%
#getting access to data shape attribute
df_exams.shape
# Out:
# (1000, 8)

# %%
#display and rows
pd.set_option('display.max_rows', 1000)
df_exams

# %%
df_exams.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
#get access to column attribute
df_exams.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
#daatypes of each columns
df_exams.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
df_exams.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
df_exams.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
len(df_exams)
# Out:
# 1000

# %%
max(df_exams.index)
# Out:
# 999

# %%
min(df_exams.index)
# Out:
# 0

# %%
#obtaining datatype
type(df_exams)
# Out:
# pandas.core.frame.DataFrame

# %%
#rounding the value of the dataframe
round(df_exams, 2)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
# [1000 rows x 8 columns]

# %%
#selecting one columns in  dataframe
df_exams['gender']
# Out:
# 0      female
# 1      female
# 2      female
# 3        male
# 4        male
#         ...
# 995    female
# 996      male
# 997    female
# 998    female
# 999    female
# Name: gender, Length: 1000, dtype: object

# %%
#checkout datatype
type(df_exams['gender'])
# Out:
# pandas.core.series.Series

# %%
df_exams['gender'].index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
df_exams['gender'].index
df_exams['gender'].head()
# Out:
# 0    female
# 1    female
# 2    female
# 3      male
# 4      male
# Name: gender, dtype: object

# %%
df_exams.gender
# Out:
# 0      female
# 1      female
# 2      female
# 3        male
# 4        male
#         ...
# 995    female
# 996      male
# 997    female
# 998    female
# 999    female
# Name: gender, Length: 1000, dtype: object

# %%
df_exams['math score']
# Out:
# 0      72
# 1      69
# 2      90
# 3      47
# 4      76
#        ..
# 995    88
# 996    62
# 997    59
# 998    68
# 999    77
# Name: math score, Length: 1000, dtype: int64

# %%
df_exams[['gender', 'math score']]
# Out:
#      gender  math score
# 0    female          72
# 1    female          69
# 2    female          90
# 3      male          47
# 4      male          76
# ..      ...         ...
# 995  female          88
# 996    male          62
# 997  female          59
# 998  female          68
# 999  female          77
#
# [1000 rows x 2 columns]

# %%
type(df_exams[['gender', 'math score']])
# Out:
# pandas.core.frame.DataFrame

# %%
df_exams[['gender', 'math score', 'reading score', 'reading score']]
# Out:
#      gender  math score  reading score  reading score
# 0    female          72             72             72
# 1    female          69             90             90
# 2    female          90             95             95
# 3      male          47             57             57
# 4      male          76             78             78
# ..      ...         ...            ...            ...
# 995  female          88             99             99
# 996    male          62             55             55
# 997  female          59             71             71
# 998  female          68             78             78
# 999  female          77             86             86
#
# [1000 rows x 4 columns]

# %%
#adding a new column in te dataframe
df_exams['language score'] = 17
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#      language score
# 0                17
# 1                17
# 2                17
# 3                17
# 4                17
# ..              ...
# 995              17
# 996              17
# 997              17
# 998              17
# 999              17
#
# [1000 rows x 9 columns]

# %%
#add arrays with numpy

import numpy as np

# %%
language_score = np.arange(0, 1000)

# %%
len(language_score)
# Out:
# 1000

# %%
#adding new column to dataframe with an array
df_exams['language score'] = language_score
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#      language score
# 0                 0
# 1                 1
# 2                 2
# 3                 3
# 4                 4
# ..              ...
# 995             995
# 996             996
# 997             997
# 998             998
# 999             999
#
# [1000 rows x 9 columns]

# %%
#create random integer number
int_language_score = np.random.randint(1, 100, size=1000)

# %%
#min and max value
min(int_language_score)
max(int_language_score)
# Out:
# 99

# %%
#adding new column to dataframe 
df_exams['language_score'] = int_language_score
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#      language score  language_score
# 0                 0              56
# 1                 1              96
# 2                 2              41
# 3                 3              28
# 4                 4              39
# ..              ...             ...
# 995             995              22
# 996             996              86
# 997             997              50
# 998             998              72
# 999             999              86
#
# [1000 rows x 10 columns]

# %%
#creating random float numbers
np.random.uniform(1, 100, size=1000)
# Out:
# array([37.70874038, 85.12555796, 49.52628041, 81.13923273, 96.85246433,
#        22.83963248,  1.5332228 , 16.7096248 , 51.44325606, 70.33072102,
#        42.01793813, 68.22547025, 54.64612334, 12.87895554, 81.09849504,
#        59.49090064, 90.27910566, 74.73389321, 34.69507255, 91.85679168,
#        94.57206144, 53.57737219, 35.32124354, 57.12693998, 95.5845007 ,
#        30.45403272, 48.11778261, 98.34917619, 65.61926049, 48.60596834,
#        55.50675906, 50.74418876, 36.49495   , 21.82091561, 18.88028355,
#        75.45047337, 87.27690739, 65.56705671, 86.30085751, 53.94916137,
#        24.46149173, 71.67796764, 21.47842545,  8.08897375,  4.22697228,
#        56.17078145, 33.96432267, 84.71799287, 26.18897824, 78.48707916,
#        44.14911893, 98.07001689, 50.60213667, 41.87619845, 80.70933746,
#         7.49243356, 66.57468897, 94.32931862, 79.99916591, 17.41061154,
#        19.46645005, 56.98842388, 40.8669568 , 82.5607504 , 33.57583364,
#        78.51896518, 85.56689999,  6.95966458, 96.38698714, 92.49755951,
#        83.35336738,  4.65165375, 88.72618671, 31.17515859, 52.23986049,
#        80.12756034,  5.05657101, 43.79108334,  6.27694777, 25.72520867,
#         1.75707905, 16.06047311, 96.46923346, 93.26203969, 99.50224203,
#        56.24915387, 68.4124787 , 65.67481498, 96.4261048 , 48.61423449,
#         2.85117872, 80.96188879, 42.14734349, 51.80089936, 59.53702073,
#        11.34871565, 72.19093609, 14.27023389, 41.58628869, 53.87226145,
#        24.19630854, 75.87356406, 97.03835213, 25.48780118, 53.53153439,
#         6.40227717, 56.22333   , 58.18529253, 19.66203903, 20.61255155,
#        82.72601277, 48.62184893, 52.65514374, 49.62078922, 96.58178731,
#        35.90991333,  5.65596224, 72.06547453, 52.0902893 , 61.41076863,
#         2.39412334, 51.95968738, 57.64400488, 33.93849022, 72.18240969,
#        60.2513811 , 42.72373165, 88.79769602, 71.60720095, 32.32108726,
#        62.33212592, 10.03517321, 15.1360333 , 76.38817232, 59.20692698,
#        94.83098669, 24.91178905, 27.93596778, 19.88803643, 79.41157584,
#        52.15028334, 33.37425804, 10.38085063, 92.2843838 , 53.84875307,
#        86.73216771, 64.74174154, 15.5886586 , 70.75136049, 17.82412812,
#        14.71098714, 95.66728033,  9.0400697 , 54.39953276,  1.52985634])

# %%
#maths operators in a dataframe
df_exams['math score'].sum()
# Out:
# 66089

# %%
df_exams['math score'].count()
df_exams['math score'].mean()
df_exams['math score'].std()
df_exams['math score'].min()
# Out:
# 0

# %%
df_exams.describe()
# Out:
#        math score  reading score  writing score  language score  \
# count  1000.00000    1000.000000    1000.000000     1000.000000
# mean     66.08900      69.169000      68.054000      499.500000
# std      15.16308      14.600192      15.195657      288.819436
# min       0.00000      17.000000      10.000000        0.000000
# 25%      57.00000      59.000000      57.750000      249.750000
# 50%      66.00000      70.000000      69.000000      499.500000
# 75%      77.00000      79.000000      79.000000      749.250000
# max     100.00000     100.000000     100.000000      999.000000
#
#        language_score
# count      1000.00000
# mean         50.08500
# std          28.15675
# min           1.00000
# 25%          25.00000
# 50%          51.00000
# 75%          74.00000
# max          99.00000

# %%
df_exams['math score']	+ df_exams['reading score'] + df_exams['writing score']
# Out:
# 0      218
# 1      247
# 2      278
# 3      148
# 4      229
#       ...
# 995    282
# 996    172
# 997    195
# 998    223
# 999    249
# Length: 1000, dtype: int64

# %%
df_exams['average'] = (df_exams['math score']	+ df_exams['reading score'] + df_exams['writing score'])/3
df_exams.round(2)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#      language score  language_score  average
# 0                 0              56    72.67
# 1                 1              96    82.33
# 2                 2              41    92.67
# 3                 3              28    49.33
# 4                 4              39    76.33
# ..              ...             ...      ...
# 995             995              22    94.00
# 996             996              86    57.33
# 997             997              50    65.00
# 998             998              72    74.33
# 999             999              86    83.00
#
# [1000 rows x 11 columns]

# %%
#value counts
#len of dataframe
len(df_exams['gender'])
df_exams['gender'].count()
# Out:
# 1000

# %%
#counting value data
df_exams['gender'].value_counts()
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %%
#return the relative frequency
df_exams['gender'].value_counts(normalize=True)
# Out:
# female    0.518
# male      0.482
# Name: gender, dtype: float64

# %%
#counting parents level of education
df_exams['parental level of education'].value_counts()
# Out:
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: parental level of education, dtype: int64

# %%
df_exams['parental level of education'].value_counts(normalize=True).round(2)
# Out:
# some college          0.23
# associate's degree    0.22
# high school           0.20
# some high school      0.18
# bachelor's degree     0.12
# master's degree       0.06
# Name: parental level of education, dtype: float64

# %%
#Sort a dataframe
df_exams.sort_values('math score')
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 59   female        group C            some high school  free/reduced
# 980  female        group B                 high school  free/reduced
# 17   female        group B            some high school  free/reduced
# 787  female        group B                some college      standard
# 145  female        group C                some college  free/reduced
# ..      ...            ...                         ...           ...
# 625    male        group D                some college      standard
# 623    male        group A                some college      standard
# 451  female        group E                some college      standard
# 962  female        group E          associate's degree      standard
# 149    male        group E          associate's degree  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 59                     none           0             17             10
# 980                    none           8             24             23
# 17                     none          18             32             28
# 787                    none          19             38             32
# 145                    none          22             39             33
# ..                      ...         ...            ...            ...
# 625               completed         100             97             99
# 623               completed         100             96             86
# 451                    none         100             92             97
# 962                    none         100            100            100
# 149               completed         100            100             93
#
#      language score  language_score     average
# 59               59              32    9.000000
# 980             980              57   18.333333
# 17               17              19   26.000000
# 787             787              78   29.666667
# 145             145              10   31.333333
# ..              ...             ...         ...
# 625             625              18   98.666667
# 623             623               5   94.000000
# 451             451              86   96.333333
# 962             962              94  100.000000
# 149             149              79   97.666667
#
# [1000 rows x 11 columns]

# %%
#sort data descending in order
df_exams.sort_values('math score', ascending=False)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 962  female        group E          associate's degree      standard
# 625    male        group D                some college      standard
# 458  female        group E           bachelor's degree      standard
# 623    male        group A                some college      standard
# 451  female        group E                some college      standard
# ..      ...            ...                         ...           ...
# 145  female        group C                some college  free/reduced
# 787  female        group B                some college      standard
# 17   female        group B            some high school  free/reduced
# 980  female        group B                 high school  free/reduced
# 59   female        group C            some high school  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 962                    none         100            100            100
# 625               completed         100             97             99
# 458                    none         100            100            100
# 623               completed         100             96             86
# 451                    none         100             92             97
# ..                      ...         ...            ...            ...
# 145                    none          22             39             33
# 787                    none          19             38             32
# 17                     none          18             32             28
# 980                    none           8             24             23
# 59                     none           0             17             10
#
#      language score  language_score     average
# 962             962              94  100.000000
# 625             625              18   98.666667
# 458             458              72  100.000000
# 623             623               5   94.000000
# 451             451              86   96.333333
# ..              ...             ...         ...
# 145             145              10   31.333333
# 787             787              78   29.666667
# 17               17              19   26.000000
# 980             980              57   18.333333
# 59               59              32    9.000000
#
# [1000 rows x 11 columns]

# %%
# sort descending by multiple columns
df_exams.sort_values(['math score', 'reading score'], ascending=False)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 149    male        group E          associate's degree  free/reduced
# 458  female        group E           bachelor's degree      standard
# 916    male        group E           bachelor's degree      standard
# 962  female        group E          associate's degree      standard
# 625    male        group D                some college      standard
# ..      ...            ...                         ...           ...
# 145  female        group C                some college  free/reduced
# 787  female        group B                some college      standard
# 17   female        group B            some high school  free/reduced
# 980  female        group B                 high school  free/reduced
# 59   female        group C            some high school  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 149               completed         100            100             93
# 458                    none         100            100            100
# 916               completed         100            100            100
# 962                    none         100            100            100
# 625               completed         100             97             99
# ..                      ...         ...            ...            ...
# 145                    none          22             39             33
# 787                    none          19             38             32
# 17                     none          18             32             28
# 980                    none           8             24             23
# 59                     none           0             17             10
#
#      language score  language_score     average
# 149             149              79   97.666667
# 458             458              72  100.000000
# 916             916              30  100.000000
# 962             962              94  100.000000
# 625             625              18   98.666667
# ..              ...             ...         ...
# 145             145              10   31.333333
# 787             787              78   29.666667
# 17               17              19   26.000000
# 980             980              57   18.333333
# 59               59              32    9.000000
#
# [1000 rows x 11 columns]

# %%
# sort descending by multiple columns and updating columns
df_exams.sort_values(['math score', 'reading score'], ascending=False, inplace=True)

# %%
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 149    male        group E          associate's degree  free/reduced
# 458  female        group E           bachelor's degree      standard
# 916    male        group E           bachelor's degree      standard
# 962  female        group E          associate's degree      standard
# 625    male        group D                some college      standard
# ..      ...            ...                         ...           ...
# 145  female        group C                some college  free/reduced
# 787  female        group B                some college      standard
# 17   female        group B            some high school  free/reduced
# 980  female        group B                 high school  free/reduced
# 59   female        group C            some high school  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 149               completed         100            100             93
# 458                    none         100            100            100
# 916               completed         100            100            100
# 962                    none         100            100            100
# 625               completed         100             97             99
# ..                      ...         ...            ...            ...
# 145                    none          22             39             33
# 787                    none          19             38             32
# 17                     none          18             32             28
# 980                    none           8             24             23
# 59                     none           0             17             10
#
#      language score  language_score     average
# 149             149              79   97.666667
# 458             458              72  100.000000
# 916             916              30  100.000000
# 962             962              94  100.000000
# 625             625              18   98.666667
# ..              ...             ...         ...
# 145             145              10   31.333333
# 787             787              78   29.666667
# 17               17              19   26.000000
# 980             980              57   18.333333
# 59               59              32    9.000000
#
# [1000 rows x 11 columns]

# %%
# sort descending with key and values
df_exams

# %%
df_exams.sort_values('race/ethnicity', ascending=True, key=lambda col:col.str.lower())
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 741  female        group A          associate's degree  free/reduced
# 151    male        group A           bachelor's degree      standard
# 811    male        group A                 high school  free/reduced
# 112    male        group A          associate's degree      standard
# 25     male        group A             master's degree  free/reduced
# ..      ...            ...                         ...           ...
# 751    male        group E                some college      standard
# 915  female        group E                some college      standard
# 592    male        group E           bachelor's degree      standard
# 479    male        group E          associate's degree      standard
# 517  female        group E                some college      standard
#
#     test preparation course  math score  reading score  writing score  \
# 741                    none          37             57             56
# 151                    none          77             67             68
# 811                    none          45             47             49
# 112                    none          54             53             47
# 25                     none          73             74             72
# ..                      ...         ...            ...            ...
# 751                    none          68             72             65
# 915                    none          68             70             66
# 592                    none          68             68             64
# 479                    none          76             71             67
# 517               completed          66             74             73
#
#      language score  language_score    average
# 741             741              56  50.000000
# 151             151              42  70.666667
# 811             811              34  47.000000
# 112             112              42  51.333333
# 25               25              65  73.000000
# ..              ...             ...        ...
# 751             751              36  68.333333
# 915             915              69  68.000000
# 592             592              34  66.666667
# 479             479              98  71.333333
# 517             517              24  71.000000
#
# [1000 rows x 11 columns]
